# %% [markdown]
# ## Data Gathering
# In the cell below, gather **all** three pieces of data for this project and load them in the notebook. **Note:** the methods required to gather each data are different.
# 1. Directly download the WeRateDogs Twitter archive data (twitter_archive_enhanced.csv)

# %%
import pandas as pd
import numpy as np
import requests
import os
import json
from PIL import Image
from io import BytesIO
import tweepy
from tweepy import OAuthHandler
import json
import seaborn as sb
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
tweet_archive = pd.read_csv('twitter-archive-enhanced.csv')
tweet_archive.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
# ...

# %% [markdown]
# 2. Use the Requests library to download the tweet image prediction (image_predictions.tsv)

# %%
url_image = "https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv"
r_image= requests.get(url_image)

open('image_predictions.tsv', 'wb').write(r_image.content)
# Out:
# 335079

# %%
df_image = pd.read_csv('image_predictions.tsv', sep = '\t')
df_image
# Out:
#                 tweet_id                                            jpg_url  \
# 0     666020888022790149    https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1     666029285002620928    https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2     666033412701032449    https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3     666044226329800704    https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4     666049248165822465    https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
# 5     666050758794694657    https://pbs.twimg.com/media/CT5Jof1WUAEuVxN.jpg
# 6     666051853826850816    https://pbs.twimg.com/media/CT5KoJ1WoAAJash.jpg
# 7     666055525042405380    https://pbs.twimg.com/media/CT5N9tpXIAAifs1.jpg
# 8     666057090499244032    https://pbs.twimg.com/media/CT5PY90WoAAQGLo.jpg
# 9     666058600524156928    https://pbs.twimg.com/media/CT5Qw94XAAA_2dP.jpg
# 10    666063827256086533    https://pbs.twimg.com/media/CT5Vg_wXIAAXfnj.jpg
# ...

# %% [markdown]
# 3. Use the Tweepy library to query additional data via the Twitter API (tweet_json.txt)

# %%
#consumer_key = 'HIDDEN'
#consumer_secret = 'HIDDEN'
#access_token = 'HIDDEN'
#access_secret = 'HIDDEN'


auth = tweepy.OAuthHandler('5Uur0mo4ol2kB8yhtZ1VxXS0u', 'h8E7fSpXWiMoBel7G1ZOAeu4Mgru0v0MtxH5ehYE1RKM89SiBH')
auth.set_access_token('303562412-ct9aNnU0FQR0UKJVn1i1W3Y8omqSewiQWUcRaygB', 'D3qslrbdOU5fqTOp951kOIuZbkeTPBodnjNYoEGFR63Ft')

#auth = OAuthHandler(consumer_key, consumer_secret)
#auth.set_access_token(access_token, access_secret)

api = tweepy.API(auth, wait_on_rate_limit=True)

# %%
df_tweetjson = pd.DataFrame(columns=['tweet_id', 'retweet_count', 'favorite_count'])
with open('tweetjson.txt') as file:
    for data in file:
        tweet = json.loads(data)
        tweet_id = tweet['id_str']
        retweet_count = tweet['retweet_count']
        favorite_count = tweet['favorite_count']
        df_tweetjson = df_tweetjson.append(pd.DataFrame([[tweet_id, retweet_count, favorite_count]],
        columns=['tweet_id', 'retweet_count', 'favorite_count']))
        df_tweetjson = df_tweetjson.reset_index(drop=True)

# %%
df_tweetjson.head()
# Out:
#              tweet_id retweet_count favorite_count
# 0  892420643555336193          8853          39467
# 1  892177421306343426          6514          33819
# 2  891815181378084864          4328          25461
# 3  891689557279858688          8964          42908
# 4  891327558926688256          9774          41048

# %% [markdown]
# ## Assessing Data
# In this section, detect and document at least **eight (8) quality issues and two (2) tidiness issue**. You must use **both** visual assessment
# programmatic assessement to assess the data.
#
# **Note:** pay attention to the following key points when you access the data.
#
# * You only want original ratings (no retweets) that have images. Though there are 5000+ tweets in the dataset, not all are dog ratings and some are retweets.
# * Assessing and cleaning the entire dataset completely would require a lot of time, and is not necessary to practice and demonstrate your skills in data wrangling. Therefore, the requirements of this project are only to assess and clean at least 8 quality issues and at least 2 tidiness issues in this dataset.
# * The fact that the rating numerators are greater than the denominators does not need to be cleaned. This [unique rating system](http://knowyourmeme.com/memes/theyre-good-dogs-brent) is a big part of the popularity of WeRateDogs.
# * You do not need to gather the tweets beyond August 1st, 2017. You can, but note that you won't be able to gather the image predictions for these tweets since you don't have access to the algorithm used.

# %%
tweet_archive.tail(15)
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 2341  666094000022159362                    NaN                  NaN
# 2342  666082916733198337                    NaN                  NaN
# 2343  666073100786774016                    NaN                  NaN
# 2344  666071193221509120                    NaN                  NaN
# 2345  666063827256086533                    NaN                  NaN
# 2346  666058600524156928                    NaN                  NaN
# 2347  666057090499244032                    NaN                  NaN
# 2348  666055525042405380                    NaN                  NaN
# 2349  666051853826850816                    NaN                  NaN
# 2350  666050758794694657                    NaN                  NaN
# 2351  666049248165822465                    NaN                  NaN
# 2352  666044226329800704                    NaN                  NaN
# 2353  666033412701032449                    NaN                  NaN
# ...

# %%
tweet_archive.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
# tweet_id                      2356 non-null int64
# in_reply_to_status_id         78 non-null float64
# in_reply_to_user_id           78 non-null float64
# timestamp                     2356 non-null object
# source                        2356 non-null object
# text                          2356 non-null object
# retweeted_status_id           181 non-null float64
# retweeted_status_user_id      181 non-null float64
# retweeted_status_timestamp    181 non-null object
# expanded_urls                 2297 non-null object
# rating_numerator              2356 non-null int64
# rating_denominator            2356 non-null int64
# name                          2356 non-null object
# doggo                         2356 non-null object
# floofer                       2356 non-null object
# pupper                        2356 non-null object
# ...

# %%
tweet_archive.shape
# Out:
# (2356, 17)

# %%
tweet_archive.isnull().sum()
# Out:
# tweet_id                         0
# in_reply_to_status_id         2278
# in_reply_to_user_id           2278
# timestamp                        0
# source                           0
# text                             0
# retweeted_status_id           2175
# retweeted_status_user_id      2175
# retweeted_status_timestamp    2175
# expanded_urls                   59
# rating_numerator                 0
# rating_denominator               0
# name                             0
# doggo                            0
# floofer                          0
# pupper                           0
# puppo                            0
# dtype: int64

# %%
tweet_archive.duplicated().sum()
# Out:
# 0

# %%
tweet_archive.describe()
# Out:
#            tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# count  2.356000e+03           7.800000e+01         7.800000e+01
# mean   7.427716e+17           7.455079e+17         2.014171e+16
# std    6.856705e+16           7.582492e+16         1.252797e+17
# min    6.660209e+17           6.658147e+17         1.185634e+07
# 25%    6.783989e+17           6.757419e+17         3.086374e+08
# 50%    7.196279e+17           7.038708e+17         4.196984e+09
# 75%    7.993373e+17           8.257804e+17         4.196984e+09
# max    8.924206e+17           8.862664e+17         8.405479e+17
#
#        retweeted_status_id  retweeted_status_user_id  rating_numerator  \
# count         1.810000e+02              1.810000e+02       2356.000000
# mean          7.720400e+17              1.241698e+16         13.126486
# std           6.236928e+16              9.599254e+16         45.876648
# min           6.661041e+17              7.832140e+05          0.000000
# ...

# %%
tweet_archive.name.value_counts()
# Out:
# None       745
# a           55
# Charlie     12
# Oliver      11
# Lucy        11
# Cooper      11
# Tucker      10
# Lola        10
# Penny       10
# Bo           9
# Winston      9
# Sadie        8
# the          8
# an           7
# Daisy        7
# Toby         7
# Bailey       7
# Buddy        7
# Milo         6
# Jack         6
# Oscar        6
# Jax          6
# Koda         6
# Bella        6
# Rusty        6
# Leo          6
# Dave         6
# Scout        6
# Stanley      6
# George       5
#           ...
# Cheesy       1
# Horace       1
# Cupid        1
# Pumpkin      1
# Rinna        1
# Vinnie       1
# Chuck        1
# Halo         1
# Caryl        1
# Fwed         1
# Jangle       1
# Wishes       1
# Wafer        1
# Wiggles      1
# Bowie        1
# Spark        1
# Boston       1
# Roscoe       1
# Pippin       1
# Marq         1
# light        1
# Kial         1
# Jett         1
# Rorie        1
# Geno         1
# Ginger       1
# Beebop       1
# ...

# %%
tweet_archive.doggo.value_counts()
# Out:
# None     2259
# doggo      97
# Name: doggo, dtype: int64

# %%
tweet_archive.floofer.value_counts()
# Out:
# None       2346
# floofer      10
# Name: floofer, dtype: int64

# %%
tweet_archive.pupper.value_counts()
# Out:
# None      2099
# pupper     257
# Name: pupper, dtype: int64

# %%
tweet_archive.puppo.value_counts()
# Out:
# None     2326
# puppo      30
# Name: puppo, dtype: int64

# %%
tweet_archive.rating_numerator.value_counts()
# Out:
# 12      558
# 11      464
# 10      461
# 13      351
# 9       158
# 8       102
# 7        55
# 14       54
# 5        37
# 6        32
# 3        19
# 4        17
# 1         9
# 2         9
# 420       2
# 0         2
# 15        2
# 75        2
# 80        1
# 20        1
# 24        1
# 26        1
# 44        1
# 50        1
# 60        1
# 165       1
# 84        1
# 88        1
# 144       1
# 182       1
# 143       1
# 666       1
# 960       1
# 1776      1
# 17        1
# 27        1
# 45        1
# 99        1
# 121       1
# 204       1
# Name: rating_numerator, dtype: int64

# %%
tweet_archive.rating_denominator.value_counts()
# Out:
# 10     2333
# 11        3
# 50        3
# 80        2
# 20        2
# 2         1
# 16        1
# 40        1
# 70        1
# 15        1
# 90        1
# 110       1
# 120       1
# 130       1
# 150       1
# 170       1
# 7         1
# 0         1
# Name: rating_denominator, dtype: int64

# %%
df_image.head(20)
# Out:
#               tweet_id                                          jpg_url  \
# 0   666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1   666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2   666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3   666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4   666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
# 5   666050758794694657  https://pbs.twimg.com/media/CT5Jof1WUAEuVxN.jpg
# 6   666051853826850816  https://pbs.twimg.com/media/CT5KoJ1WoAAJash.jpg
# 7   666055525042405380  https://pbs.twimg.com/media/CT5N9tpXIAAifs1.jpg
# 8   666057090499244032  https://pbs.twimg.com/media/CT5PY90WoAAQGLo.jpg
# 9   666058600524156928  https://pbs.twimg.com/media/CT5Qw94XAAA_2dP.jpg
# 10  666063827256086533  https://pbs.twimg.com/media/CT5Vg_wXIAAXfnj.jpg
# 11  666071193221509120  https://pbs.twimg.com/media/CT5cN_3WEAAlOoZ.jpg
# ...

# %%
df_image.info(), df_image.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
# tweet_id    2075 non-null int64
# jpg_url     2075 non-null object
# img_num     2075 non-null int64
# p1          2075 non-null object
# p1_conf     2075 non-null float64
# p1_dog      2075 non-null bool
# p2          2075 non-null object
# p2_conf     2075 non-null float64
# p2_dog      2075 non-null bool
# p3          2075 non-null object
# p3_conf     2075 non-null float64
# p3_dog      2075 non-null bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB
# (None, (2075, 12))

# %%
df_image.isnull().sum()
# Out:
# tweet_id    0
# jpg_url     0
# img_num     0
# p1          0
# p1_conf     0
# p1_dog      0
# p2          0
# p2_conf     0
# p2_dog      0
# p3          0
# p3_conf     0
# p3_dog      0
# dtype: int64

# %%
df_image.duplicated().sum()
# Out:
# 0

# %%
df_image.describe()
# Out:
#            tweet_id      img_num      p1_conf       p2_conf       p3_conf
# count  2.075000e+03  2075.000000  2075.000000  2.075000e+03  2.075000e+03
# mean   7.384514e+17     1.203855     0.594548  1.345886e-01  6.032417e-02
# std    6.785203e+16     0.561875     0.271174  1.006657e-01  5.090593e-02
# min    6.660209e+17     1.000000     0.044333  1.011300e-08  1.740170e-10
# 25%    6.764835e+17     1.000000     0.364412  5.388625e-02  1.622240e-02
# 50%    7.119988e+17     1.000000     0.588230  1.181810e-01  4.944380e-02
# 75%    7.932034e+17     1.000000     0.843855  1.955655e-01  9.180755e-02
# max    8.924206e+17     4.000000     1.000000  4.880140e-01  2.734190e-01

# %%
df_tweetjson.head(20)
# Out:
#               tweet_id retweet_count favorite_count
# 0   892420643555336193          8853          39467
# 1   892177421306343426          6514          33819
# 2   891815181378084864          4328          25461
# 3   891689557279858688          8964          42908
# 4   891327558926688256          9774          41048
# 5   891087950875897856          3261          20562
# 6   890971913173991426          2158          12041
# 7   890729181411237888         16716          56848
# 8   890609185150312448          4429          28226
# 9   890240255349198849          7711          32467
# 10  890006608113172480          7624          31166
# 11  889880896479866881          5156          28268
# 12  889665388333682689          8538          38818
# 13  889638837579907072          4735          27672
# 14  889531135344209921          2321          15359
# 15  889278841981685760          5637          25652
# 16  888917238123831296          4709          29611
# ...

# %%
df_tweetjson.info(), df_tweetjson.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2354 entries, 0 to 2353
# Data columns (total 3 columns):
# tweet_id          2354 non-null object
# retweet_count     2354 non-null object
# favorite_count    2354 non-null object
# dtypes: object(3)
# memory usage: 55.2+ KB
# (None, (2354, 3))

# %%
df_tweetjson.describe()
# Out:
#                   tweet_id  retweet_count  favorite_count
# count                 2354           2354            2354
# unique                2354           1724            2007
# top     753398408988139520           3652               0
# freq                     1              5             179

# %% [markdown]
# ### Quality issues
# 1. There are missing values in the in_reply_to_instatus_id, in_reply_to_user_id, retweeted_status_id, retweeted_status_user_id, retweeted_status_timestamp columns.
#
# 2. Convert tweet Id to object data type
#
# 3. The timestamp and retweeted_status_timestamp should be datetime objects.
#
# 4. There are missing values in the doggo, pupper, floofer and puppo columns.
#
# 5. The rating denominator has 0 as one of it values.
#
#
# ##### Df-image prediction dataset
# 6. Missing records, as there are only 2075 of 2354 records.
#
#
# ##### df_tweetjson
#
#  There are some missing records, as there are 2354 of 2356 records.
#
# 7. The data types are recorded as string instead of integer.
#
# 8. Convert dog state to categorical data.
# 9. The tweet sources to be extracted from the url.

# %% [markdown]
# ### Tidiness issues
# 1. The dog stages in the tweet_archieve dataset were grouped into multiple columns. We would need to merge them all into one column.
#
# 2. The df_tweetjson data, df_imsge and the tweet_archieve data, should be merged to form one dataset.

# %% [markdown]
# ## Cleaning Data
# In this section, clean **all** of the issues you documented while assessing.
#
# **Note:** Make a copy of the original data before cleaning. Cleaning includes merging individual pieces of data according to the rules of [tidy data](https://cran.r-project.org/web/packages/tidyr/vignettes/tidy-data.html). The result should be a high-quality and tidy master pandas DataFrame (or DataFrames, if appropriate).

# %%
# Make copies of original pieces of data
clean_archieve = tweet_archive.copy()
clean_image = df_image.copy()
clean_tweetjson = df_tweetjson.copy()

# %%
all_columns = pd.Series(list(clean_archieve) + list(clean_image) + list(clean_tweetjson))
all_columns[all_columns.duplicated()]
# Out:
# 17    tweet_id
# 29    tweet_id
# dtype: object

# %% [markdown]
# ## Tidiness Issues

# %% [markdown]
# ### Issue #1: We have 3 different datasets to work with

# %% [markdown]
# #### Define : Merge the df_tweetjson data, df_imsge and the tweet_archieve data  to form one dataset.

# %% [markdown]
# #### Code

# %%
all_df = pd.concat([clean_archieve, clean_image, clean_tweetjson], join = 'outer', axis = 1)

# %% [markdown]
# #### Test

# %%
all_df.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
# ...

# %% [markdown]
# ### Issue #2: Different columns for all the dog stages

# %% [markdown]
# #### Define: Merge all the dog stages into one column.

# %% [markdown]
# #### Code

# %%
all_df.columns
# Out:
# Index(['tweet_id', 'in_reply_to_status_id', 'in_reply_to_user_id', 'timestamp',
#        'source', 'text', 'retweeted_status_id', 'retweeted_status_user_id',
#        'retweeted_status_timestamp', 'expanded_urls', 'rating_numerator',
#        'rating_denominator', 'name', 'doggo', 'floofer', 'pupper', 'puppo',
#        'tweet_id', 'jpg_url', 'img_num', 'p1', 'p1_conf', 'p1_dog', 'p2',
#        'p2_conf', 'p2_dog', 'p3', 'p3_conf', 'p3_dog', 'tweet_id',
#        'retweet_count', 'favorite_count'],
#       dtype='object')

# %%
all_df['dog_stage'] = all_df['text'].str.extract('(doggo|floofer|pupper|puppo)')

# %%
#all_df.head(20)
all_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 33 columns):
# tweet_id                      2356 non-null int64
# in_reply_to_status_id         78 non-null float64
# in_reply_to_user_id           78 non-null float64
# timestamp                     2356 non-null object
# source                        2356 non-null object
# text                          2356 non-null object
# retweeted_status_id           181 non-null float64
# retweeted_status_user_id      181 non-null float64
# retweeted_status_timestamp    181 non-null object
# expanded_urls                 2297 non-null object
# rating_numerator              2356 non-null int64
# rating_denominator            2356 non-null int64
# name                          2356 non-null object
# doggo                         2356 non-null object
# floofer                       2356 non-null object
# pupper                        2356 non-null object
# ...

# %%
all_df.drop(['doggo','floofer','pupper','puppo'],inplace = True, axis = 1)

# %% [markdown]
# #### Test

# %%
all_df.dog_stage.value_counts()
# Out:
# pupper     265
# doggo       93
# puppo       37
# floofer      4
# Name: dog_stage, dtype: int64

# %% [markdown]
# ## QUALITY ISSUES

# %% [markdown]
# ### Issue #1: Missing values in the in_reply_to_instatus_id, in_reply_to_user_id, retweeted_status_id, retweeted_status_user_id, retweeted_status_timestamp columns

# %% [markdown]
# #### Define: Drop columns with many missing values.

# %% [markdown]
# #### Code

# %%
col_drop = ['in_reply_to_status_id', 'in_reply_to_user_id', 'retweeted_status_id', 'retweeted_status_user_id', 'retweeted_status_timestamp','expanded_urls']
all_df.drop(columns = col_drop, inplace = True, axis = 1)

# %% [markdown]
# #### Test

# %%
all_df.head()
# Out:
#              tweet_id                  timestamp  \
# 0  892420643555336193  2017-08-01 16:23:56 +0000
# 1  892177421306343426  2017-08-01 00:17:27 +0000
# 2  891815181378084864  2017-07-31 00:18:03 +0000
# 3  891689557279858688  2017-07-30 15:58:51 +0000
# 4  891327558926688256  2017-07-29 16:00:24 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  rating_numerator  \
# 0  This is Phineas. He's a mystical boy. Only eve...                13
# 1  This is Tilly. She's just checking pup on you....                13
# 2  This is Archie. He is a rare Norwegian Pouncin...                12
# ...

# %% [markdown]
# ### Issue #2: Tweet Id colum is a recorded as int data type.

# %% [markdown]
# #### Define: Convert tweet_id column to an object data type.

# %% [markdown]
# #### Code

# %%
all_df['tweet_id'] = all_df['tweet_id'].astype('object')

# %% [markdown]
# #### Test

# %%
all_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 23 columns):
# tweet_id              2356 non-null object
# timestamp             2356 non-null object
# source                2356 non-null object
# text                  2356 non-null object
# rating_numerator      2356 non-null int64
# rating_denominator    2356 non-null int64
# name                  2356 non-null object
# tweet_id              2075 non-null object
# jpg_url               2075 non-null object
# img_num               2075 non-null float64
# p1                    2075 non-null object
# p1_conf               2075 non-null float64
# p1_dog                2075 non-null object
# p2                    2075 non-null object
# p2_conf               2075 non-null float64
# p2_dog                2075 non-null object
# p3                    2075 non-null object
# p3_conf               2075 non-null float64
# p3_dog                2075 non-null object
# ...

# %% [markdown]
# ### Issue #3: Tweet_id in multiple columns

# %% [markdown]
# #### Define: Drop two of the three duplicate column

# %% [markdown]
# #### Code

# %%
all_df.columns.duplicated()
# Out:
# array([False, False, False, False, False, False, False,  True, False,
#        False, False, False, False, False, False, False, False, False,
#        False,  True, False, False, False], dtype=bool)

# %%
all_df = all_df.loc[:,~all_df.columns.duplicated()]
all_df.columns
# Out:
# Index(['tweet_id', 'timestamp', 'source', 'text', 'rating_numerator',
#        'rating_denominator', 'name', 'jpg_url', 'img_num', 'p1', 'p1_conf',
#        'p1_dog', 'p2', 'p2_conf', 'p2_dog', 'p3', 'p3_conf', 'p3_dog',
#        'retweet_count', 'favorite_count', 'dog_stage'],
#       dtype='object')

# %% [markdown]
# #### Test

# %%
all_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 21 columns):
# tweet_id              2356 non-null object
# timestamp             2356 non-null object
# source                2356 non-null object
# text                  2356 non-null object
# rating_numerator      2356 non-null int64
# rating_denominator    2356 non-null int64
# name                  2356 non-null object
# jpg_url               2075 non-null object
# img_num               2075 non-null float64
# p1                    2075 non-null object
# p1_conf               2075 non-null float64
# p1_dog                2075 non-null object
# p2                    2075 non-null object
# p2_conf               2075 non-null float64
# p2_dog                2075 non-null object
# p3                    2075 non-null object
# p3_conf               2075 non-null float64
# p3_dog                2075 non-null object
# retweet_count         2354 non-null object
# ...

# %%
all_df.source.value_counts()
# Out:
# <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>     2221
# <a href="http://vine.co" rel="nofollow">Vine - Make a Scene</a>                          91
# <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>                       33
# <a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>      11
# Name: source, dtype: int64

# %% [markdown]
# #### Test

# %% [markdown]
# ### Issue # 4:  Wrong data type recorded for timestamp

# %% [markdown]
# #### Define: Convert the time stamp column to a datetime object.

# %% [markdown]
# #### Code

# %%
all_df['timestamp'] = pd.to_datetime(all_df['timestamp'], format='%Y-%m-%d %H:%M:%S')

# %% [markdown]
# #### Test

# %%
all_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 21 columns):
# tweet_id              2356 non-null object
# timestamp             2356 non-null datetime64[ns]
# source                2356 non-null object
# text                  2356 non-null object
# rating_numerator      2356 non-null int64
# rating_denominator    2356 non-null int64
# name                  2356 non-null object
# jpg_url               2075 non-null object
# img_num               2075 non-null float64
# p1                    2075 non-null object
# p1_conf               2075 non-null float64
# p1_dog                2075 non-null object
# p2                    2075 non-null object
# p2_conf               2075 non-null float64
# p2_dog                2075 non-null object
# p3                    2075 non-null object
# p3_conf               2075 non-null float64
# p3_dog                2075 non-null object
# retweet_count         2354 non-null object
# ...

# %% [markdown]
# ### Issue #5: Missing rows

# %% [markdown]
# #### Define: Drop missing rows

# %% [markdown]
# ####  Code

# %%
all_df.dropna(subset = ['p1', 'p1_conf', 'p1_dog', 'p2', 'p2_conf', 'p2_dog', 'p3', 'p3_conf','p3_dog', 'retweet_count', 'favorite_count'], inplace = True)

# %% [markdown]
# #### Test

# %%
all_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2075 entries, 0 to 2074
# Data columns (total 21 columns):
# tweet_id              2075 non-null object
# timestamp             2075 non-null datetime64[ns]
# source                2075 non-null object
# text                  2075 non-null object
# rating_numerator      2075 non-null int64
# rating_denominator    2075 non-null int64
# name                  2075 non-null object
# jpg_url               2075 non-null object
# img_num               2075 non-null float64
# p1                    2075 non-null object
# p1_conf               2075 non-null float64
# p1_dog                2075 non-null object
# p2                    2075 non-null object
# p2_conf               2075 non-null float64
# p2_dog                2075 non-null object
# p3                    2075 non-null object
# p3_conf               2075 non-null float64
# p3_dog                2075 non-null object
# retweet_count         2075 non-null object
# ...

# %% [markdown]
# ### Issue #6: Many empty rows in the dog stage column.

# %% [markdown]
# #### Define: Fill with None values

# %% [markdown]
# #### Code

# %%
all_df['dog_stage'] = all_df['dog_stage'].fillna('None')

# %% [markdown]
# #### Test

# %%
all_df.dog_stage.value_counts()
# Out:
# None       1677
# pupper      264
# doggo        93
# puppo        37
# floofer       4
# Name: dog_stage, dtype: int64

# %% [markdown]
# ### Issue #7: Wrong data type for dog stage column

# %% [markdown]
# #### Define: Change data type to category.

# %% [markdown]
# #### Code

# %%
all_df.dog_stage= all_df.dog_stage.astype('category')

# %% [markdown]
# #### Test

# %%
all_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2075 entries, 0 to 2074
# Data columns (total 21 columns):
# tweet_id              2075 non-null object
# timestamp             2075 non-null datetime64[ns]
# source                2075 non-null object
# text                  2075 non-null object
# rating_numerator      2075 non-null int64
# rating_denominator    2075 non-null int64
# name                  2075 non-null object
# jpg_url               2075 non-null object
# img_num               2075 non-null float64
# p1                    2075 non-null object
# p1_conf               2075 non-null float64
# p1_dog                2075 non-null object
# p2                    2075 non-null object
# p2_conf               2075 non-null float64
# p2_dog                2075 non-null object
# p3                    2075 non-null object
# p3_conf               2075 non-null float64
# p3_dog                2075 non-null object
# retweet_count         2075 non-null object
# ...

# %% [markdown]
# ### Issue #8: Ratings have wrong data type.

# %% [markdown]
# #### Define: Change the ratings data type to float.

# %% [markdown]
# #### Code

# %%
all_df['rating_numerator']= all_df['rating_numerator'].astype(float)
all_df['rating_denominator']= all_df['rating_denominator'].astype(float)

# %%
all_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2075 entries, 0 to 2074
# Data columns (total 21 columns):
# tweet_id              2075 non-null object
# timestamp             2075 non-null datetime64[ns]
# source                2075 non-null object
# text                  2075 non-null object
# rating_numerator      2075 non-null float64
# rating_denominator    2075 non-null float64
# name                  2075 non-null object
# jpg_url               2075 non-null object
# img_num               2075 non-null float64
# p1                    2075 non-null object
# p1_conf               2075 non-null float64
# p1_dog                2075 non-null object
# p2                    2075 non-null object
# p2_conf               2075 non-null float64
# p2_dog                2075 non-null object
# p3                    2075 non-null object
# p3_conf               2075 non-null float64
# p3_dog                2075 non-null object
# retweet_count         2075 non-null object
# ...

# %% [markdown]
# ### Issue #9: Source recorded as url

# %% [markdown]
# #### Define: Extract the source from the url

# %% [markdown]
# #### Code

# %%
source_split = all_df["source"].str.split('"', expand = True)[1].str.split('/',expand=True)[4]
source_split
all_df["source"] = source_split

# %% [markdown]
# #### Test

# %%
all_df.source.value_counts()
# Out:
# iphone       1962
# tweetdeck      11
# Name: source, dtype: int64

# %% [markdown]
# ## Storing Data
# Save gathered, assessed, and cleaned master dataset to a CSV file named "twitter_archive_master.csv".

# %%
all_df.to_csv('twitter_archive_master.csv', encoding ='utf-8', index = False)

# %% [markdown]
# ## Analyzing and Visualizing Data
# In this section, analyze and visualize your wrangled data. You must produce at least **three (3) insights and one (1) visualization.**

# %% [markdown]
# ### Visualization

# %%
sb.countplot(data=all_df[all_df.source != np.nan],x='source')
plt.savefig("tweet_source.png", bbox_inches='tight')

# %%
plt.figure(1)

plt.subplot(141)
base_color = sb.color_palette()[0]
all_df['p1'].value_counts(normalize = True).head(10).plot.bar(color=base_color,figsize=(24,6), fontsize =15.0)
plt.title('Prediction 1', fontsize = 22.0)
plt.ylabel('Count in %', fontsize = 20.0)

plt.subplot(142)
all_df['p2'].value_counts(normalize = True).head(10).plot.bar(color=base_color,figsize=(24,6), fontsize =15.0)
plt.title('Prediction 2', fontsize = 22.0)
plt.ylabel('Count in %', fontsize = 20.0)

plt.subplot(143)
all_df['p1'].value_counts(normalize = True).head(10).plot.bar(color=base_color,figsize=(24,6), fontsize =15.0)
plt.title('Prediction 3', fontsize = 22.0)
plt.ylabel('Count in %', fontsize = 20.0)
plt.suptitle('Dog class predictions by 3 Algorithm',fontweight="bold", fontsize = 25.0)
plt.savefig("dogs_class_pred.png", bbox_inches='tight')

# %% [markdown]
# ### Insights:
# 1. The most predicted dog species for the first and the third algorith was the golden retriever.
#
# 2. The labrador retriever was most predicted in the second algorithm.
#
# 3. Most of the tweets were from Iphone which accounts for 95% of the tweets.
